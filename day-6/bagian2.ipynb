# %% [markdown]
# [12/09/2022] **Penulisan ini diupdate** - Pembaruan isi dokumen dan materi pembelajaran.

# %% [markdown]
# ## **BAGIAN 2: SQL Session**
#
# Ini merupakan pembelajaran untuk materi sql, selamat mengerjakan!

# %% [markdown]
# Nonik merupakan tim pendatang baru dalam mengelola database, dan kamu ditantang oleh Alex selaku kepala divisi database tentang kasus berikut ini.
#
# Cara akses database sebagai berikut ini:
#
# ```python
# import psycopg2 as pg
# import pandas.io.sql as psql
# import pandas as pd
#
# # Bangun konektivitas
# host = "ec2-54-164-22-242.compute-1.amazonaws.com"
# dbname = "d92sarup3qlji0"
# user = "fttxsdmckdfikz"
# password = "c5561e667cd292f382a0e437807e05c89fba1b894dddff1e77e07befe8a866ac"
# connection = pg.connect(f"host={host} dbname={dbname} user={user} password={password}")
#
# # Function SQL
# def sql(doc):
#     return psql.read_sql_query(doc, connection)
# ```

# %% [markdown]
# **STUDI KASUS 1: Biaya Penyimpanan Produk di Gudang**
#
# Kamu diminta oleh Alex untuk menampilkan 5 produk utama yang memiliki beban terbesar dan terkecil dalam gudang?
#
# (Buatkan grafik - Opsional)

# %%
# RESUME

# %%
# Silahkan dicoba disini

# %% [markdown]
# **STUDI KASUS 2: Keuntungan Produk di Gudang**
#
# Kamu diminta oleh Alex untuk menampilkan 5 produk utama yang memiliki keuntungan terbesar dan terkecil?
#
# (Buatkan grafik - Opsional)

# %%
# RESUME

# %%
# Silahkan dicoba disini

# %% [markdown]
# **STUDI KASUS 3: Siapa Pembeli yang sering memesan?**
#
# Kamu diminta oleh Alex untuk menampilkan 5 orang yang memiliki transaksi terbesar maupun terkecil?
#
# (Buatkan grafik - Opsional)

# %%
# Silahkan dicoba disini

# %% [markdown]
# **STUDI KASUS 4: Kota banyak/sedikit import?**
#
# Kamu diminta oleh Alex untuk menampilkan 5 kota yang menerima import terbanyak dan terkecil?
#
# (Buatkan grafik - Opsional)

# %%
# Silahkan dicoba disini

# %% [markdown]
# **STUDI KASUS 5: Buat alamat lengkap**
#
# Kamu diminta oleh Alex untuk membuat kolom baru yang berisikan alamat lengkap [alamat, kota, kode pos dan nomor telephone] simpan dalam excel dan download.

# %%
# Silahkan dicoba disini

# %% [markdown]
# **STUDI KASUS 6: Finalisasi**
#
# Buatlah kesimpulan dari studi kasus 1 dan 4, keputusan apa yang akan kamu lakukan?

# %%
# Silahkan dicoba disini
